# %%
import torchvision

valid_set = torchvision.datasets.ImageNet(root='/data/ILSVRC2012_img_val')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-becb56023841> in <module>()
#       1 import torchvision
#       2
# ----> 3 valid_set = torchvision.datasets.ImageNet(root='/data/ILSVRC2012_img_val')
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/imagenet.py in __init__(self, root, split, download, **kwargs)
#      53         self.split = verify_str_arg(split, "split", ("train", "val"))
#      54
# ---> 55         self.parse_archives()
#      56         wnid_to_classes = load_meta_file(self.root)[0]
#      57
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/imagenet.py in parse_archives(self)
#      68     def parse_archives(self) -> None:
#      69         if not check_integrity(os.path.join(self.root, META_FILE)):
# ---> 70             parse_devkit_archive(self.root)
#      71
# ...
