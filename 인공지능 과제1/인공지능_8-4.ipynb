# %%
def step(v, direction, step_size):  ## 업데이트
  return[v_i + step_size * direction_i for v_i, direction_i in zip(v, direction)]

def sum_of_squares_gradient(v): ## 도함수 구하기
  return[2 * v_i for v_i in v]

v = [1,1]
epoch = 1001
tolerance = 0.001
for i in range(epoch):
  gradient = sum_of_squares_gradient(v)
  next_v = step(v, gradient, -0.01)
  v = next_v
  if v == 0.001:
    break
  if i %200 == 0:
    print(v)
# Out:
# [0.98, 0.98]
# [0.017236187673607125, 0.017236187673607125]
# [0.0003031491484895982, 0.0003031491484895982]
# [5.331771037205014e-06, 5.331771037205014e-06]
# [9.377490431629441e-08, 9.377490431629441e-08]
# [1.6493080100716338e-09, 1.6493080100716338e-09]
